# %% [markdown]
# **Outline of Report**

# %% [markdown]
# **Introduction:**
#
# Talk about our objective of classifying chocolates, by trying two models

# %% [markdown]
# **Background + justification of design choices**
#
# *YOLOv8-inspired model Overview:*
#
# Provide a brief description of the YOLOv8 architecture, highlighting its relevance to the task. add diagrams from papers
#
# Can maybe mention that we tested yolo's ultralytics first as a proof of concept. include stats on that
#
# *Simplified DDETR Overview:*
#
# Discuss the DDETR model, comparing to yolo
#
#
# add citations

# %% [markdown]
# **Data and Preprocessing:**
#
# Talk about annotations, and data augmentations

# %% [markdown]
# **technical description / Model Architecture:**
#
# (from niyazi's msg )The schematic of the model we created. Showing the dimension changes and the purpose of the every layer with their sublayer functionalities.
#
# *YOLOv8:*
# present the architecture of our code, and explain decisions, what is different from yolo source code
#
# *Simplified DDETR:*
# same here, highlight what's different from source code
#
# *Training Strategy:*
# optimizers, learning rates, data augmentation was applied during training, etc
#
#
# hyper parameter tuning?

# %% [markdown]
# **Results**
#
#
# *Quantitative Evaluation: Strong quantitative and qualitative analysis, demonstrating and explaining the ability of your solution to segment the chocolates from the background and to compute relevant descriptors for each chocolate type, through means of metrics and visualizations (e.g. confusion matrix, class response heatmaps, clustering metrics, high-dimensional separability, learned filter visualization, etc.)*
#
# from niyazi: Creating some loss graphs and the metrics like mAP50 and mAP50-95 as a result of the training and their interpretation.
#
# maybe add in time it takes to run, how much time per image, number of epochs, etc
#
#
# try to explain the results?
#
# compare the two models, assuming we can make the ddetr work well. otherwise, focus on yolo and we can make a separate section just on ddetr saying why we tried it and why it didn't work out
#
# for ddetr, attention map? for both, maybe we can try doing visualization of the learned features

# %% [markdown]
# **Qualitative Evaluation**
#
# talk ab data augmentation and non-max suppression
#
# Visualizations of the results, showing example images of model's predictions + interpret them
#
# compare the two models in their segmentations and class predictions, maybe we can figure out if there are certain features or kinds of chocolates the models can distinguish better and try to explain why
#
# maybe we can choose some images that we think are particularly challenging and see how the model does
#
# look at the errors, where the models fail
#
#
#
# **Analysis of Performance / summary**
#
# give strengths and weaknesses of each model, evaluate our best model's performance
#
#
# suggest potential improvements

# %% [markdown]
# references
